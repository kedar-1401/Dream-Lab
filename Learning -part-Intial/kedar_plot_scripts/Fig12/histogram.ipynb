# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# area = (0, 360.23, 37.47, 18.98)
# percentage = (100, 20.59, 55.88, 58.82)
# percentage_under = (100, 23.53, 61.76, 73.53)

area = (360.23, 37.47, 18.98)
percentage = (20.59, 55.88, 58.82)
percentage_under = (23.53, 61.76, 73.53)

# Subtract every element in percentage and percentage_under from 100
area = tuple(x / 33 for x in area)
percentage = tuple(100 - x for x in percentage)
percentage_under = tuple(100 - x for x in percentage_under)

# Figure size
fig, ax1 = plt.subplots(figsize=(4, 6))
#colors = ['#fb9a3c', '#be4986', '#fadc6f', '#e36668']
colors = ['#be4986', '#fadc6f', '#e36668']

# Width of a bar
width = 0.2

# Bar plot for normalized area on the left y-axis
# ax1.bar((0, 0.2, 0.4, 0.6), area, width, color=colors, edgecolor='darkgrey')
ax1.bar((0.2, 0.4, 0.6), area, width, color=colors, edgecolor='darkgrey')

ax1.set_ylim(0, 20)
# ax1.set_ylabel('Normalized Area', fontsize=22)

# ax1.tick_params(axis='x', which='minor', bottom=False)
# ax1.tick_params(axis='both', which='major', labelsize=16)
ax1.set_axisbelow(True)
# Set custom ticks for the left y-axis
ax1.set_yticks([0, 4, 8, 12, 16, 20])

ax1.tick_params(axis='x', which='minor', bottom=False)
ax1.tick_params(axis='both', which='major', labelsize=28)

# Add gridlines
ax1.yaxis.grid(which='major', linestyle='-', linewidth='0.5', color='darkgrey', alpha=1)
ax1.yaxis.grid(which='minor', linestyle='-', linewidth='0.25', color='lightgray')
ax1.minorticks_on()

locations = [0.2, 1.4, 2.4]
labels = ['Area', 'A/L', 'A/L+1']
ax1.set_xticks(locations,labels, rotation=45)


# ax2.tick_params(axis='x', which='minor', bottom=False)
ax1.tick_params(axis='y', which='major', labelsize=24)

# Create a second y-axis (right) and share the same x-axis
ax2 = ax1.twinx()
# ax2.bar((1, 1.2, 1.4, 1.6), percentage, width, color=colors, edgecolor='darkgrey')
# ax2.bar((2, 2.2, 2.4, 2.6), percentage_under, width, color=colors, edgecolor='darkgrey')
ax2.bar((1.2, 1.4, 1.6), percentage, width, color=colors, edgecolor='darkgrey')
ax2.bar((2.2, 2.4, 2.6), percentage_under, width, color=colors, edgecolor='darkgrey')


ax2.set_ylim(0, 100)
# ax2.set_ylabel('Percentage (%)', fontsize=22)

# Add a vertical dotted line
ax1.axvline(x=(0.775), color='grey', linestyle='-', linewidth=3)




# ax2.tick_params(axis='x', which='minor', bottom=False)
ax2.tick_params(axis='y', which='major', labelsize=24)
ax2.minorticks_on()

# Axis at below = false
ax2.set_axisbelow(True)

# Write text on the plot
# plt.text(-0.1, 2, '0', fontsize=16)
# plt.text(0.9, 2, '0', fontsize=16)
# plt.text(1.9, 2, '0', fontsize=16)

# Create patches for the legend
#patch1 = mpatches.Patch(color='#fb9a3c', label='ANL')
patch2 = mpatches.Patch(color='#be4986', label='MAX')
patch3 = mpatches.Patch(color='#fadc6f', label='NN')
patch4 = mpatches.Patch(color='#e36668', label='TL')

# Add the legend to the plot
# plt.legend(handles=[patch1, patch2, patch3, patch4], loc='upper right')



plt.tight_layout()

plt.savefig('PowerError_Mobnet.pdf', dpi=300, bbox_inches='tight', format='pdf')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# area = (0, 581.76, 57.08, 14.58)
# percentage = (100, 0, 61.76, 64.70)
# percentage_under = (100, 0, 64.70, 79.41)

area = (581.76, 57.08, 14.58)
percentage = (0, 61.76, 64.70)
percentage_under = (0, 64.70, 79.41)

# Subtract every element in percentage and percentage_under from 100
area = tuple(x / 33 for x in area)
percentage = tuple(100 - x for x in percentage)
percentage_under = tuple(100 - x for x in percentage_under)

# Figure size
fig, ax1 = plt.subplots(figsize=(4, 6))
# colors = ['#fb9a3c', '#be4986', '#fadc6f', '#e36668']
colors = ['#be4986', '#fadc6f', '#e36668']

# Width of a bar
width = 0.2

# Bar plot for normalized area on the left y-axis
# ax1.bar((0, 0.2, 0.4, 0.6), area, width, color=colors, edgecolor='darkgrey')
ax1.bar((0.2, 0.4, 0.6), area, width, color=colors, edgecolor='darkgrey')

ax1.set_ylim(0, 20)
ax1.set_ylabel('Normalized Area', fontsize=28) ##########

ax1.tick_params(axis='x', which='minor', bottom=False)
ax1.tick_params(axis='both', which='major', labelsize=28)
ax1.set_axisbelow(True)
# Set custom ticks for the left y-axis
ax1.set_yticks([0, 4, 8, 12, 16, 20])


# Add gridlines
ax1.yaxis.grid(which='major', linestyle='-', linewidth='0.5', color='darkgrey', alpha=1)     ############
ax1.yaxis.grid(which='minor', linestyle='-', linewidth='0.25', color='lightgrey')       ############
ax1.minorticks_on()

locations = [0.2, 1.4, 2.4]        ##########
labels = ['Area', 'A/L', 'A/L+1']
ax1.set_xticks(locations,labels, rotation=45)
ax1.tick_params(axis='y', which='major', labelsize=24) ###########

# Create a second y-axis (right) and share the same x-axis
ax2 = ax1.twinx()
# ax2.bar((1, 1.2, 1.4, 1.6), percentage, width, color=colors, edgecolor='darkgrey')
# ax2.bar((2, 2.2, 2.4, 2.6), percentage_under, width, color=colors, edgecolor='darkgrey')
ax2.bar((1.2, 1.4, 1.6), percentage, width, color=colors, edgecolor='darkgrey')
ax2.bar((2.2, 2.4, 2.6), percentage_under, width, color=colors, edgecolor='darkgrey')
ax2.set_ylim(0, 100)
# ax2.set_ylabel('Percentage (%)', fontsize=24)   ###########

# Add a vertical dotted line
ax1.axvline(x=(0.775), color='grey', linestyle='-', linewidth=3) ########



# ax2.tick_params(axis='x', which='minor', bottom=False)
ax2.tick_params(axis='y', which='major', labelsize=24)
ax2.minorticks_on()

# Axis at below = false
ax2.set_axisbelow(True)

# # Write text on the plot
# plt.text(-0.1, 2, '0', fontsize=16)
# plt.text(0.9, 2, '0', fontsize=16)
# plt.text(1.9, 2, '0', fontsize=16)

# Create patches for the legend
# patch1 = mpatches.Patch(color='#fb9a3c', label='ANL')
patch2 = mpatches.Patch(color='#be4986', label='MAX')
patch3 = mpatches.Patch(color='#fadc6f', label='NN')
patch4 = mpatches.Patch(color='#e36668', label='PT')

# Add the legend to the plot
# plt.legend(handles=[patch1, patch2, patch3, patch4], loc='upper right')
plt.tight_layout()

plt.savefig('PowerError_Resnet.pdf', dpi=300, bbox_inches='tight',format='pdf')
# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# area = (2.1, 14.84, 25.67, 0)
# percentage = (91.18, 79.41, 76.47, 100)
# percentage_under = (97.06, 82.35, 79.41, 100)

# area = (0, 25.67, 1.55, 12.24)
# percentage = (100, 76.47, 91.17, 79.41)
# percentage_under = (100, 79.41, 100, 85.29)

area = (25.67, 1.55, 12.24)
percentage = (76.47, 91.17, 79.41)
percentage_under = (79.41, 100, 85.29)

# Subtract every element in percentage and percentage_under from 100
area = tuple(x / 33 for x in area)
percentage = tuple(100 - x for x in percentage)
percentage_under = tuple(100 - x for x in percentage_under)

# Figure size
fig, ax1 = plt.subplots(figsize=(4, 6))
# colors = ['#fb9a3c', '#be4986', '#fadc6f', '#e36668']
colors = ['#be4986', '#fadc6f', '#e36668']

# Width of a bar
width = 0.2

# Bar plot for normalized area on the left y-axis
ax1.bar((0.2, 0.4, 0.6), area, width, color=colors, edgecolor='darkgrey')
ax1.set_ylim(0, 20)
# ax1.set_ylabel('Normalized Area', fontsize=24)

# ax1.tick_params(axis='x', which='minor', bottom=False)
# ax1.minorticks_on()
# ax1.tick_params(axis='both', which='major', labelsize=24)
# ax1.set_axisbelow(True)
# Set custom ticks for the left y-axis
ax1.set_yticks([0, 4, 8, 12, 16, 20])

ax1.tick_params(axis='x', which='minor', bottom=False)
ax1.tick_params(axis='both', which='major', labelsize=28)
# Add gridlines
ax1.yaxis.grid(which='major', linestyle='-', linewidth='0.5', color='darkgrey', alpha=1)     ############
ax1.yaxis.grid(which='minor', linestyle='-', linewidth='0.25', color='lightgrey')       ############
ax1.minorticks_on()

locations = [0.2, 1.4, 2.4]        ##########
labels = ['Area', 'A/L', 'A/L+1']
ax1.set_xticks(locations,labels, rotation=45)
ax1.tick_params(axis='y', which='major', labelsize=24) ###########

# Create a second y-axis (right) and share the same x-axis
ax2 = ax1.twinx()
# ax2.bar((1, 1.2, 1.4, 1.6), percentage, width, color=colors, edgecolor='darkgrey')
# ax2.bar((2, 2.2, 2.4, 2.6), percentage_under, width, color=colors, edgecolor='darkgrey')

ax2.bar((1.2, 1.4, 1.6), percentage, width, color=colors, edgecolor='darkgrey')
ax2.bar((2.2, 2.4, 2.6), percentage_under, width, color=colors, edgecolor='darkgrey')


ax2.set_ylim(0, 100)
# ax2.set_ylabel('Percentage (%)', fontsize=24)

# Add a vertical dotted line
ax1.axvline(x=(0.775), color='grey', linestyle='-', linewidth=3)



# ax2.tick_params(axis='x', which='minor', bottom=False)
ax2.tick_params(axis='y', which='major', labelsize=24)
ax2.minorticks_on()

# Axis at below = false
ax2.set_axisbelow(True)

# Write text on the plot
# plt.text(-0.1, 2, '0', fontsize=16)
# # plt.text(0.18, 5, '1.5', fontsize=14)
# plt.text(0.9, 2, '0', fontsize=16)
# plt.text(1.9, 2, '0', fontsize=16)
plt.text(2.3, 2, '0', fontsize=16)

# Create patches for the legend
# patch1 = mpatches.Patch(color='#fb9a3c', label='ANL')
patch2 = mpatches.Patch(color='#be4986', label='MAX')
patch3 = mpatches.Patch(color='#fadc6f', label='NN')
patch4 = mpatches.Patch(color='#e36668', label='PT')

# Add the legend to the plot
plt.legend(handles=[patch2, patch3, patch4], loc='upper right', fontsize=24)
plt.tight_layout()



plt.savefig('PowerError_Yolo.pdf', dpi=300, bbox_inches='tight',format='pdf')
# Show the plot
plt.show()

# %%
def convert_data(input_string):
    # Split the input string into components
    parts = input_string.split('\t')

    # Extract data for each bar color
    blue_data = [float(value) for value in parts[2].split(',')]
    orange_data = [float(value) for value in parts[3].split(',')]
    green_data = [float(value) for value in parts[4].split(',')]

    # Create the output format
    output = f"blue_bar = ({blue_data[0]}, {orange_data[0]}, {green_data[0]})\n"
    output += f"orange_bar = ({blue_data[1]}, {orange_data[1]}, {green_data[1]})\n"
    output += f"green_bar = ({blue_data[2]}, {orange_data[2]}, {green_data[2]})"

    return output

# %%
convert_data('3	Lstm	2.21, 21.12, 310.37	91.18, 67.65, 26.47	97.06, 82.35, 29.41')
# Out:
# 'blue_bar = (2.21, 91.18, 97.06)\norange_bar = (21.12, 67.65, 82.35)\ngreen_bar = (310.37, 26.47, 29.41)'

# %%
import numpy as np
import matplotlib.pyplot as plt


area = (2.21, 21.12, 310.37)
percentage = (91.18, 67.65, 26.47)
percentage_under = (97.06, 82.35, 29.41)

area = (310.37 , 21.12, 2.21)
percentage = (26.47, 67.65, 91.18)
percentage_under = (29.41, 82.35, 97.06)

# Subtract every element in percentage and percentage_under from 100
area = tuple(x / 33 for x in area)
percentage = tuple(100 - x for x in percentage)
percentage_under = tuple(100 - x for x in percentage_under)

# Figure size
fig, ax1 = plt.subplots(figsize=(4, 6))
colors = ['#be4986', '#fadc6f', '#e36668']
# Width of a bar
width = 0.2

# Bar plot for normalized area on the left y-axis
ax1.bar((0, 0.2, 0.4), area, width, color=colors, edgecolor='darkgrey')
ax1.set_ylim(0, 20)
# ax1.set_ylabel('Normalized Area', fontsize=24)

# ax1.tick_params(axis='x', which='minor', bottom=False)
# # ax1.minorticks_on()
# # ax1.tick_params(axis='both', which='major', labelsize=24)
ax1.set_axisbelow(True)
# Set custom ticks for the left y-axis
ax1.set_yticks([0, 4, 8, 12, 16, 20])

ax1.tick_params(axis='x', which='minor', bottom=False)
ax1.tick_params(axis='both', which='major', labelsize=28)
# Add gridlines
ax1.yaxis.grid(which='major', linestyle='-', linewidth='0.5', color='darkgrey', alpha=1)     ############
ax1.yaxis.grid(which='minor', linestyle='-', linewidth='0.25', color='lightgrey')       ############
ax1.minorticks_on()

locations = [0.15, 1.05, 1.85]        ##########
labels = ['Area', 'A/L', 'A/L+1']
ax1.set_xticks(locations,labels, rotation=45)
ax1.tick_params(axis='y', which='major', labelsize=24) ###########

# Create a second y-axis (right) and share the same x-axis
ax2 = ax1.twinx()
ax2.bar((0.85, 1.05, 1.25), percentage, width, color=colors, edgecolor='darkgrey')
ax2.bar((1.65, 1.85, 2.05), percentage_under, width, color=colors, edgecolor='darkgrey')
ax2.set_ylim(0, 100)
# ax2.set_ylabel('Percentage (%)', fontsize=24)

# Add a vertical dotted line
ax1.axvline(x=(0.63), color='grey', linestyle='-', linewidth=3) ########

# ax2.tick_params(axis='x', which='minor', bottom=False)
ax2.tick_params(axis='y', which='major', labelsize=24)
# # Add gridlines
# ax2.yaxis.grid(which='major', linestyle='-', linewidth='0.5', color='black', alpha=1)
# ax2.yaxis.grid(which='minor', linestyle='--', linewidth='0.25', color='gray')
ax2.minorticks_on()

# Axis at below = false
ax2.set_axisbelow(True)

# Write text on the plot
# plt.text(0.25, 4, '2.1', fontsize=10)
# plt.text(0.5, 2, '0', fontsize=14)
# plt.text(1.7, 2, '0', fontsize=14)

# Create patches for the legend
patch1 = mpatches.Patch(color='#fb9a3c', label='ANL')
patch2 = mpatches.Patch(color='#be4986', label='MAX')
patch3 = mpatches.Patch(color='#fadc6f', label='NN')
patch4 = mpatches.Patch(color='#e36668', label='TL')

# Add the legend to the plot
# plt.legend(handles=[patch2, patch3, patch4], loc='upper right')
plt.tight_layout()


plt.savefig('PowerError_LSTM.pdf', dpi=300, bbox_inches='tight',format='pdf')
# Show the plot
plt.show()

# %%
print(convert_data('4	Bert	6.9, 81.11, 771.38	70.59, 29.41, 0.0	88.24, 35.29, 0.0'))
# Out:
# blue_bar = (6.9, 70.59, 88.24)
# orange_bar = (81.11, 29.41, 35.29)
# green_bar = (771.38, 0.0, 0.0)

# %%
# area = (6.9, 81.11, 771.38)
# percentage = (70.59, 29.41, 0.0)
# percentage_under = (88.24, 35.29, 0.0)

area = (771.38, 81.11, 7.58)
percentage = (0.0, 29.41, 70.59)
percentage_under = (0.0, 35.29, 88.24)


# Subtract every element in percentage and percentage_under from 100
area = tuple(x / 33 for x in area)
percentage = tuple(100 - x for x in percentage)
percentage_under = tuple(100 - x for x in percentage_under)

# Figure size
fig, ax1 = plt.subplots(figsize=(4, 6))
colors = ['#be4986', '#fadc6f', '#e36668']
# Width of a bar
width = 0.2

# Bar plot for normalized area on the left y-axis
ax1.bar((0, 0.2, 0.4), area, width, color=colors, edgecolor='darkgrey')
ax1.set_ylim(0, 20)
# ax1.set_ylabel('Normalized Area', fontsize=24)

# ax1.tick_params(axis='x', which='minor', bottom=False)
# ax1.minorticks_on()
# ax1.tick_params(axis='both', which='major', labelsize=20)
ax1.set_axisbelow(True)
# Set custom ticks for the left y-axis
ax1.set_yticks([0, 4, 8, 12, 16, 20])

ax1.tick_params(axis='x', which='minor', bottom=False)
ax1.tick_params(axis='both', which='major', labelsize=28)
# Add gridlines
ax1.yaxis.grid(which='major', linestyle='-', linewidth='0.5', color='darkgrey', alpha=1)     ############
ax1.yaxis.grid(which='minor', linestyle='-', linewidth='0.25', color='lightgrey')       ############
ax1.minorticks_on()

locations = [0.15, 1.05, 1.85]        ##########
labels = ['Area', 'A/L', 'A/L+1']
ax1.set_xticks(locations,labels, rotation=45)
ax1.tick_params(axis='y', which='major', labelsize=24) ###########

# Create a second y-axis (right) and share the same x-axis
ax2 = ax1.twinx()
ax2.bar((0.85, 1.05, 1.25), percentage, width, color=colors, edgecolor='darkgrey')
ax2.bar((1.65, 1.85, 2.05), percentage_under, width, color=colors, edgecolor='darkgrey')
ax2.set_ylim(0, 100)
# ax2.set_ylabel('Percentage (%)', fontsize=24)

# Add a vertical dotted line
ax1.axvline(x=(0.63), color='grey', linestyle='-', linewidth=3) ########


# ax2.tick_params(axis='x', which='minor', bottom=False)
ax2.tick_params(axis='y', which='major', labelsize=24)

ax2.minorticks_on()

# Axis at below = false
ax2.set_axisbelow(True)

# Write text on the plot
plt.text(-0.14, 96, '23', fontsize=16)
# plt.text(0.9, 2, '0', fontsize=12)
# plt.text(1.9, 2, '0', fontsize=12)

# Create patches for the legend
patch1 = mpatches.Patch(color='#fb9a3c', label='ANL')
patch2 = mpatches.Patch(color='#be4986', label='MAX')
patch3 = mpatches.Patch(color='#fadc6f', label='NN')
patch4 = mpatches.Patch(color='#e36668', label='TL')

# Add the legend to the plot
# plt.legend(handles=[patch1, patch2, patch3, patch4], loc='upper right')
plt.tight_layout()

plt.savefig('PowerError_BERT.pdf', dpi=300, bbox_inches='tight',format='pdf')
# Show the plot
plt.show()

# %%
print(convert_data('5	Mobnet_IN	13.84, 21.51, 342.98	61.76, 52.94, 20.59	85.29, 73.53, 23.53'))
# Out:
# blue_bar = (13.84, 61.76, 85.29)
# orange_bar = (21.51, 52.94, 73.53)
# green_bar = (342.98, 20.59, 23.53)

# %%
import numpy as np
import matplotlib.pyplot as plt


area = (13.84, 21.51, 342.98)
percentage = (61.76, 52.94, 20.59)
percentage_under = (85.29, 73.53, 23.53)

area = (342.98, 21.51, 13.84)
percentage = (20.59, 52.94, 61.76)
percentage_under = (23.53, 73.53, 85.29)

# Subtract every element in percentage and percentage_under from 100
area = tuple(x / 33 for x in area)
percentage = tuple(100 - x for x in percentage)
percentage_under = tuple(100 - x for x in percentage_under)

# Figure size
fig, ax1 = plt.subplots(figsize=(4, 6))
colors = ['#be4986', '#fadc6f', '#e36668']
# Width of a bar
width = 0.2

# Bar plot for normalized area on the left y-axis
ax1.bar((0, 0.2, 0.4), area, width, color=colors, edgecolor='darkgrey')
ax1.set_ylim(0, 20)
# ax1.set_ylabel('Normalized Area', fontsize=24)

ax1.tick_params(axis='x', which='minor', bottom=False)
ax1.minorticks_on()
ax1.tick_params(axis='both', which='major', labelsize=24)
ax1.set_axisbelow(True)
# Set custom ticks for the left y-axis
ax1.set_yticks([0, 4, 8, 12, 16, 20])

# ax1.tick_params(axis='x', which='minor', bottom=False)
# ax1.tick_params(axis='both', which='major', labelsize=24)
# Add gridlines
ax1.yaxis.grid(which='major', linestyle='-', linewidth='0.5', color='darkgrey', alpha=1)     ############
ax1.yaxis.grid(which='minor', linestyle='-', linewidth='0.25', color='lightgrey')       ############
ax1.minorticks_on()


# Create a second y-axis (right) and share the same x-axis
locations = [0.15, 1.05, 1.85]        ##########
labels = ['Area', 'A/L', 'A/L+1']
ax1.set_xticks(locations,labels, rotation=45, fontsize=28)
ax1.tick_params(axis='y', which='major', labelsize=24) ###########

# Add a vertical dotted line
# ax1.axvline(x=(0.775), color='black', linestyle='-', linewidth=1)

ax2 = ax1.twinx()
ax2.bar((0.85, 1.05, 1.25), percentage, width, color=colors, edgecolor='darkgrey')
ax2.bar((1.65, 1.85, 2.05), percentage_under, width, color=colors, edgecolor='darkgrey')
ax2.set_ylim(0, 100)
ax2.set_ylabel('Percentage (%)', fontsize=28)

# ax2.tick_params(axis='x', which='minor', bottom=False)
ax1.axvline(x=(0.63), color='grey', linestyle='-', linewidth=3) ########
ax2.tick_params(axis='y', which='major', labelsize=24)

# # Add gridlines
# ax2.yaxis.grid(which='major', linestyle='-', linewidth='0.5', color='black', alpha=1)
# ax2.yaxis.grid(which='minor', linestyle='--', linewidth='0.25', color='gray')
ax2.minorticks_on()

# Axis at below = false
ax2.set_axisbelow(True)

# Write text on the plot
# plt.text(0.25, 4, '2.1', fontsize=10)
# plt.text(0.9, 2, '0', fontsize=12)
# plt.text(1.9, 2, '0', fontsize=12)

# Create patches for the legend
patch1 = mpatches.Patch(color='#fb9a3c', label='ANL')
patch2 = mpatches.Patch(color='#be4986', label='MAX')
patch3 = mpatches.Patch(color='#fadc6f', label='NN')
patch4 = mpatches.Patch(color='#e36668', label='PT')

# Add the legend to the plot
# plt.legend(handles=[patch2, patch3, patch4], loc='upper right')
plt.tight_layout()

plt.savefig('PowerError_MobileNet_IN.pdf', dpi=300, bbox_inches='tight',format='pdf')
# Show the plot
plt.show()

# %%
print(convert_data('6	Resnet_GLD	9.78, 36.97, 490.55	64.71, 55.88, 5.88	88.24, 64.71, 8.82'))
# Out:
# blue_bar = (9.78, 64.71, 88.24)
# orange_bar = (36.97, 55.88, 64.71)
# green_bar = (490.55, 5.88, 8.82)

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 3

blue_bar = (9.78, 64.71, 88.24)
orange_bar = (36.97, 55.88, 64.71)
green_bar = (490.55, 5.88, 8.82)

import matplotlib.patches as mpatches

area = (9.78, 36.97, 490.55)
percentage = (64.71, 55.88, 5.88)
percentage_under = (88.24, 64.71, 8.82)

area = (490.55, 36.97, 13.45)
percentage = (5.88, 55.88, 52.94)
percentage_under = (8.82, 64.71, 79.41)

# Subtract every element in percentage and percentage_under from 100
area = tuple(x / 33 for x in area)
percentage = tuple(100 - x for x in percentage)
percentage_under = tuple(100 - x for x in percentage_under)

# Figure size
fig, ax1 = plt.subplots(figsize=(4, 6))
colors = ['#be4986', '#fadc6f', '#e36668']
# Width of a bar
width = 0.2

# Bar plot for normalized area on the left y-axis
ax1.bar((0, 0.2, 0.4), area, width, color=colors, edgecolor='darkgrey')
ax1.set_ylim(0, 20)
# ax1.set_ylabel('Normalized Area', fontsize=24)

ax1.tick_params(axis='x', which='minor', bottom=False)
ax1.minorticks_on()
ax1.tick_params(axis='both', which='major', labelsize=24)
ax1.set_axisbelow(True)
# Set custom ticks for the left y-axis
ax1.set_yticks([0, 4, 8, 12, 16, 20])

# ax1.tick_params(axis='x', which='minor', bottom=False)
# ax1.tick_params(axis='both', which='major', labelsize=24)
# Add gridlines
ax1.yaxis.grid(which='major', linestyle='-', linewidth='0.5', color='darkgrey', alpha=1)     ############
ax1.yaxis.grid(which='minor', linestyle='-', linewidth='0.25', color='lightgrey')       ############
ax1.minorticks_on()


locations = [0.15, 1.05, 1.85]        ##########
labels = ['Area', 'A/L', 'A/L+1']
ax1.set_xticks(locations,labels, rotation=45, fontsize=28)
ax1.tick_params(axis='y', which='major', labelsize=24) ###########

# Create a second y-axis (right) and share the same x-axis
ax2 = ax1.twinx()
ax2.bar((0.85, 1.05, 1.25), percentage, width, color=colors, edgecolor='darkgrey')
ax2.bar((1.65, 1.85, 2.05), percentage_under, width, color=colors, edgecolor='darkgrey')
ax2.set_ylim(0, 100)
# ax2.set_ylabel('Percentage (%)', fontsize=24)

# Add a vertical dotted line
ax1.axvline(x=(0.63), color='grey', linestyle='-', linewidth=3) ########

# ax2.tick_params(axis='x', which='minor', bottom=False)
ax2.tick_params(axis='y', which='major', labelsize=24)
# # Add gridlines
# ax2.yaxis.grid(which='major', linestyle='-', linewidth='0.5', color='black', alpha=1)
# ax2.yaxis.grid(which='minor', linestyle='--', linewidth='0.25', color='gray')
ax2.minorticks_on()

# Axis at below = false
ax2.set_axisbelow(True)

# Write text on the plot
# plt.text(0.25, 4, '2.1', fontsize=10)
# plt.text(0.9, 2, '0', fontsize=12)
# plt.text(1.9, 2, '0', fontsize=12)

# Create patches for the legend
patch1 = mpatches.Patch(color='#fb9a3c', label='ANL')
patch2 = mpatches.Patch(color='#be4986', label='MAX')
patch3 = mpatches.Patch(color='#fadc6f', label='NN')
patch4 = mpatches.Patch(color='#e36668', label='TL')

# Add the legend to the plot
# plt.legend(handles=[patch2, patch3, patch4], loc='upper right')
plt.tight_layout()

plt.savefig('PowerError_Resnet_GLD.pdf', dpi=300, bbox_inches='tight',format='pdf')
# Show the plot
plt.show()
