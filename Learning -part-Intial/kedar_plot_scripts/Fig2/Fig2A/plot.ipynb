# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('file.csv')
df
# Out:
#                Powermode        DNN  Observed_Power  Our_Predicted  \
# 0  10c/1.65C/0.82G/3.19M  MobileNet           30.33          29.93
# 1  12c/2.20C/1.03G/3.19M  MobileNet           37.41          38.67
# 2  12c/1.34C/0.72G/2.13M       YOLO           16.21          14.83
# 3  10c/1.03C/1.30G/3.19M       YOLO           19.23          18.34
# 4  12c/1.65C/0.62G/3.19M     ResNet           28.63          29.98
# 5  12c/2.20C/1.23G/3.19M     ResNet           45.80          48.78
#
#    NV_Predicted
# 0          34.3
# 1          46.1
# 2          26.3
# 3          56.5
# 4          29.5
# 5          56.9

# %%
mobnet = df[0:2]
yolo = df[2:4]
resnet = df[4:6]

# %%
mobnet
# Out:
#                Powermode        DNN  Observed_Power  Our_Predicted  \
# 0  10c/1.65C/0.82G/3.19M  MobileNet           30.33          29.93
# 1  12c/2.20C/1.03G/3.19M  MobileNet           37.41          38.67
#
#    NV_Predicted
# 0          34.3
# 1          46.1

# %%
mobnet['Category'] = mobnet['Powermode'].map({'10c/1.65C/0.82G/3.19M': 'A', '12c/2.20C/1.03G/3.19M': 'B'})
# Out:
# C:\Users\Kedar Dhule\AppData\Local\Temp\ipykernel_19700\2141964651.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mobnet['Category'] = mobnet['Powermode'].map({'10c/1.65C/0.82G/3.19M': 'A', '12c/2.20C/1.03G/3.19M': 'B'})

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(5, 3))

# Plot for Category A
mobnet[mobnet['Category'] == 'A'].plot(kind='bar', x='DNN', y=['Observed_Power', 'Our_Predicted', 'NV_Predicted'], ax=axes[0], rot=0, color=['#fadc6f', '#e36668', '#c7e59b'])
axes[0].set_title('10c/1.65C/0.82G/3.19M')
axes[0].grid(which='major', linestyle='-', linewidth='0.5', color='gray')
axes[0].grid(which='minor', linestyle='--', linewidth='0.5', color='gray')
axes[0].set_axisbelow(True)

# Plot for Category B
mobnet[mobnet['Category'] == 'B'].plot(kind='bar', x='DNN', y=['Observed_Power', 'Our_Predicted', 'NV_Predicted'], ax=axes[1], rot=0, color=['#fadc6f', '#e36668', '#c7e59b'])
axes[1].set_title('12c/2.20C/1.03G/3.19M')
axes[1].grid(which='major', linestyle='-', linewidth='0.5', color='gray')
axes[1].grid(which='minor', linestyle='--', linewidth='0.5', color='gray')
axes[1].set_axisbelow(True)

plt.tight_layout()
plt.show()

# %%
yolo['Category'] = yolo['Powermode'].map({'12c/1.34C/0.72G/2.13M': 'A', '10c/1.03C/1.30G/3.19M': 'B'})
# Out:
# C:\Users\Kedar Dhule\AppData\Local\Temp\ipykernel_19700\2410729110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yolo['Category'] = yolo['Powermode'].map({'12c/1.34C/0.72G/2.13M': 'A', '10c/1.03C/1.30G/3.19M': 'B'})

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(5, 3))

# Plot for Category A
yolo[yolo['Category'] == 'A'].plot(kind='bar', x='DNN', y=['Observed_Power', 'Our_Predicted', 'NV_Predicted'], ax=axes[0], rot=0, color=['#fadc6f', '#e36668', '#c7e59b'])
axes[0].set_title('10c/1.65C/0.82G/3.19M')
axes[0].grid(which='major', linestyle='-', linewidth='0.5', color='gray')
axes[0].grid(which='minor', linestyle='--', linewidth='0.5', color='gray')
axes[0].set_axisbelow(True)

# Plot for Category B
yolo[yolo['Category'] == 'B'].plot(kind='bar', x='DNN', y=['Observed_Power', 'Our_Predicted', 'NV_Predicted'], ax=axes[1], rot=0, color=['#fadc6f', '#e36668', '#c7e59b'])
axes[1].set_title('12c/2.20C/1.03G/3.19M')
axes[1].grid(which='major', linestyle='-', linewidth='0.5', color='gray')
axes[1].grid(which='minor', linestyle='--', linewidth='0.5', color='gray')
axes[1].set_axisbelow(True)

plt.tight_layout()
plt.show()

# %%
resnet['Category'] = resnet['Powermode'].map({'12c/1.65C/0.62G/3.19M': 'A', '12c/2.20C/1.23G/3.19M': 'B'})
# Out:
# C:\Users\Kedar Dhule\AppData\Local\Temp\ipykernel_19700\1837472090.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resnet['Category'] = resnet['Powermode'].map({'12c/1.65C/0.62G/3.19M': 'A', '12c/2.20C/1.23G/3.19M': 'B'})

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(5, 3))

# Plot for Category A
resnet[resnet['Category'] == 'A'].plot(kind='bar', x='DNN', y=['Observed_Power', 'Our_Predicted', 'NV_Predicted'], ax=axes[0], rot=0, color=['#fadc6f', '#e36668', '#c7e59b'])
axes[0].set_title('10c/1.65C/0.82G/3.19M')
axes[0].grid(which='major', linestyle='-', linewidth='0.5', color='gray')
axes[0].grid(which='minor', linestyle='--', linewidth='0.5', color='gray')
axes[0].set_axisbelow(True)

# Plot for Category B
resnet[resnet['Category'] == 'B'].plot(kind='bar', x='DNN', y=['Observed_Power', 'Our_Predicted', 'NV_Predicted'], ax=axes[1], rot=0, color=['#fadc6f', '#e36668', '#c7e59b'])
axes[1].set_title('12c/2.20C/1.03G/3.19M')
axes[1].grid(which='major', linestyle='-', linewidth='0.5', color='gray')
axes[1].grid(which='minor', linestyle='--', linewidth='0.5', color='gray')
axes[1].set_axisbelow(True)

plt.tight_layout()
plt.show()

# %%
print(unique_dnn)
# Out:
# ['MobileNet']

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a single subplot
fig, axes = plt.subplots(nrows=1, figsize=(4, 6))

# Get unique DNN values for positioning
unique_dnn = mobnet['DNN'].unique()
bar_width = 0.1 # Adjust the width of each bar
bar_positions_a = (0,0.1,0.2)
bar_positions_b = (0.4,0.5,0.6)  # Shift the positions for Category B

# Plot for Category A
mobnet_a = resnet[resnet['Category'] == 'A']
axes.bar(0.1, mobnet_a['Observed_Power'], width=bar_width, label='Obs Power', color='#fadc6f')
axes.bar(0.2, mobnet_a['Our_Predicted'], width=bar_width, label='PT Pred', color='#e36668')
axes.bar(0.3, mobnet_a['NV_Predicted'], width=bar_width, label='NV Pred', color='#c7e59b')

# Plot for Category B
mobnet_b = resnet[resnet['Category'] == 'B']
axes.bar(0.5, mobnet_b['Observed_Power'], width=bar_width, label='Obs Power', color='#fadc6f')
axes.bar(0.6, mobnet_b['Our_Predicted'], width=bar_width, label='PT Pred', color='#e36668')
axes.bar(0.7, mobnet_b['NV_Predicted'], width=bar_width, label='NV Pred', color='#c7e59b')

# Set x-axis ticks and labels
# axes.set_xticks(bar_positions_a + bar_width / 2)
# axes.set_xticklabels(unique_dnn)
axes.set_ylim(0,60)
axes.tick_params(axis='x', which='minor', bottom=False)
axes.tick_params(axis='both', which='major', labelsize=16)



axes.yaxis.grid(which='major', linestyle='-', linewidth='0.5', color='black', alpha=1)
axes.yaxis.grid(which='minor', linestyle='-', linewidth='0.25', color='gray')
axes.minorticks_on()
axes.set_xticks([0.2, 0.6],["PWM C","PWM D"], fontsize=16)
axes.set_axisbelow(True)

axes.set_ylabel("Power (W)", fontsize=16)

# Get handles and labels
handles, labels = axes.get_legend_handles_labels()

# Remove duplicates
handle_dict = dict(zip(labels, handles))
axes.legend(handle_dict.values(), handle_dict.keys(), loc='upper left', fontsize=16)
# axes.legend()

plt.tight_layout()
plt.savefig('motivation_nv_pred_resnet.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a single subplot
fig, axes = plt.subplots(nrows=1, figsize=(4, 6))

# Get unique DNN values for positioning
unique_dnn = mobnet['DNN'].unique()
bar_width = 0.1 # Adjust the width of each bar
bar_positions_a = (0,0.1,0.2)
bar_positions_b = (0.4,0.5,0.6)  # Shift the positions for Category B

# Plot for Category A
mobnet_a = yolo[yolo['Category'] == 'A']
axes.bar(0.1, mobnet_a['Observed_Power'], width=bar_width, label='Obs Power', color='#fadc6f')
axes.bar(0.2, mobnet_a['Our_Predicted'], width=bar_width, label='PT Pred', color='#e36668')
axes.bar(0.3, mobnet_a['NV_Predicted'], width=bar_width, label='NV Pred', color='#c7e59b')

# Plot for Category B
mobnet_b = yolo[yolo['Category'] == 'B']
axes.bar(0.5, mobnet_b['Observed_Power'], width=bar_width, label='Obs Power', color='#fadc6f')
axes.bar(0.6, mobnet_b['Our_Predicted'], width=bar_width, label='Our Pred', color='#e36668')
axes.bar(0.7, mobnet_b['NV_Predicted'], width=bar_width, label='NV Pred', color='#c7e59b')

# Set x-axis ticks and labels
# axes.set_xticks(bar_positions_a + bar_width / 2)
# axes.set_xticklabels(unique_dnn)
axes.set_ylim(0,60)
axes.tick_params(axis='x', which='minor', bottom=False)
axes.tick_params(axis='both', which='major', labelsize=16)



axes.yaxis.grid(which='major', linestyle='-', linewidth='0.5', color='black', alpha=1)
axes.yaxis.grid(which='minor', linestyle='--', linewidth='0.25', color='gray')
axes.minorticks_on()
axes.set_xticks([0.2, 0.6],["PWM E","PWM F"], fontsize=16)
axes.set_axisbelow(True)

axes.set_ylabel("Power (W)", fontsize=16)

# Get handles and labels
handles, labels = axes.get_legend_handles_labels()

# Remove duplicates
handle_dict = dict(zip(labels, handles))
axes.legend(handle_dict.values(), handle_dict.keys(), loc='upper left', fontsize=16)
# axes.legend()

plt.tight_layout()
plt.savefig('motivation_nv_pred_yolo.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a single subplot
fig, axes = plt.subplots(nrows=1, figsize=(4, 5))

# Get unique DNN values for positioning
unique_dnn = mobnet['DNN'].unique()
bar_width = 0.1 # Adjust the width of each bar
bar_positions_a = (0,0.1,0.2)
bar_positions_b = (0.4,0.5,0.6)  # Shift the positions for Category B

label_pt = "PT Pow."
label_nv = "NV Pow."

# Plot for Category A
mobnet_a = resnet[resnet['Category'] == 'A']
# axes.bar(0.1, mobnet_a['Observed_Power'], width=bar_width, label='Obs Power', color='#7bccc4',edgecolor='darkgray', linewidth=1)
axes.bar(0.4, np.abs((mobnet_a['Observed_Power'] - mobnet_a['Our_Predicted'])/mobnet_a['Observed_Power']*100), width=bar_width, label=label_pt, color='#e36668',edgecolor='darkgray', linewidth=1)
axes.bar(0.3, np.abs((mobnet_a['Observed_Power'] - mobnet_a['NV_Predicted'])/mobnet_a['Observed_Power']*100), width=bar_width, label=label_nv, color='#7bccc4', edgecolor='darkgray', linewidth=1)

# Plot for Category B
mobnet_b = resnet[resnet['Category'] == 'B']
# axes.bar(0.5, mobnet_b['Observed_Power'], width=bar_width, label='Obs Power', color='#7bccc4',edgecolor='darkgray', linewidth=1)
axes.bar(0.7, np.abs((mobnet_b['Observed_Power'] - mobnet_b['Our_Predicted'])/mobnet_b['Observed_Power']*100), width=bar_width, label=label_pt, color='#e36668',edgecolor='darkgray', linewidth=1)
axes.bar(0.6,np.abs((mobnet_b['Observed_Power'] - mobnet_b['NV_Predicted'])/mobnet_b['Observed_Power']*100), width=bar_width, label=label_nv, color='#7bccc4', edgecolor='darkgray', linewidth=1)

mobnet_a = mobnet[mobnet['Category'] == 'A']
# axes.bar(0.9, mobnet_a['Observed_Power'], width=bar_width, label='Obs Power', color='#7bccc4',edgecolor='darkgray', linewidth=1)
axes.bar(1.0,  np.abs((mobnet_a['Observed_Power'] - mobnet_a['Our_Predicted'])/mobnet_a['Observed_Power']*100), width=bar_width, label=label_pt, color='#e36668',edgecolor='darkgray', linewidth=1)
axes.bar(0.9, np.abs((mobnet_a['Observed_Power'] - mobnet_a['NV_Predicted'])/mobnet_a['Observed_Power']*100), width=bar_width, label=label_nv, color='#7bccc4', edgecolor='darkgray', linewidth=1)

# Plot for Category B
mobnet_b = mobnet[mobnet['Category'] == 'B']
# axes.bar(1.3, mobnet_b['Observed_Power'], width=bar_width, label='Obs Power', color='#7bccc4',edgecolor='darkgray', linewidth=1)
axes.bar(1.3, np.abs((mobnet_b['Observed_Power'] - mobnet_b['Our_Predicted'])/mobnet_b['Observed_Power']*100), width=bar_width, label=label_pt, color='#e36668',edgecolor='darkgray', linewidth=1)
axes.bar(1.2, np.abs((mobnet_b['Observed_Power'] - mobnet_b['NV_Predicted'])/mobnet_b['Observed_Power'])*100, width=bar_width, label=label_nv, color='#7bccc4', edgecolor='darkgray', linewidth=1)

# mobnet_a = yolo[yolo['Category'] == 'A']
# # axes.bar(1.7, mobnet_a['Observed_Power'], width=bar_width, label='Obs Power', color='#7bccc4',edgecolor='darkgray', linewidth=1)
# axes.bar(1.6,  np.abs((mobnet_a['Observed_Power'] - mobnet_a['Our_Predicted'])/mobnet_a['Observed_Power']*100), width=bar_width, label=label_pt, color='#e36668',edgecolor='darkgray', linewidth=1)
# axes.bar(1.5, np.abs((mobnet_a['Observed_Power'] - mobnet_a['NV_Predicted'])/mobnet_a['Observed_Power']*100), width=bar_width, label=label_nv, color='#7bccc4', edgecolor='darkgray', linewidth=1)

# # Plot for Category B
# mobnet_b = yolo[yolo['Category'] == 'B']
# # axes.bar(2.1, mobnet_b['Observed_Power'], width=bar_width, label='Obs Power', color='#7bccc4',edgecolor='darkgray', linewidth=1)
# axes.bar(1.9, np.abs((mobnet_b['Observed_Power'] - mobnet_b['Our_Predicted'])/mobnet_b['Observed_Power']*100), width=bar_width, label=label_pt, color='#e36668',edgecolor='darkgray', linewidth=1)
# axes.bar(1.8, np.abs((mobnet_b['Observed_Power'] - mobnet_b['NV_Predicted'])/mobnet_b['Observed_Power']*100), width=bar_width, label=label_nv, color='#7bccc4', edgecolor='darkgray', linewidth=1)


# Set x-axis ticks and labels
# axes.set_xticks(bar_positions_a + bar_width / 2)
# axes.set_xticklabels(unique_dnn)
axes.set_ylim(0,40)
axes.set_yticks([0,10,20,30,40])
axes.tick_params(axis='x', which='minor', bottom=False)




axes.yaxis.grid(which='major', linestyle='-', linewidth='0.5', color='darkgrey', alpha=1)
axes.yaxis.grid(which='minor', linestyle='-', linewidth='0.25', color='lightgray')
axes.minorticks_on()
axes.set_xticks([0.35, 0.65, 0.95,1.25],["PM1","PM2","PM3","PM4"], fontsize=16)
axes.tick_params(axis='both', which='major', labelsize=20)
axes.set_axisbelow(True)
# axes.text(0.05, -10, 'PM-', fontsize=14)
# y_label = axes.set_ylabel("Pow. Pred. MAPE (%)", fontsize=16)
# # y_label.set_position((-1,0.5))
# y_label.set_x(-10)
axes.text(-0.05,20,"Pow. Pred. MAPE (%)", fontsize=20, rotation=90, verticalalignment='center', horizontalalignment='center')
# axes.text(1.7,95,"194")
axes.text(0.3,41,"ResNet", fontsize=20, style='italic')
axes.text(0.85,41,"MobileNet", fontsize=20, style='italic')
# axes.text(1.57,105,"YOLO", fontsize=14, style='italic')


#add verticle line
axes.axvline(x=0.8, color='black', linestyle='-', linewidth=1,clip_on=False,ymax=1.1,ymin=-0.1)
# axes.axvline(x=1.395, color='black', linestyle='-', linewidth=1,clip_on=False,ymax=1.1, ymin=-0.1)
# axes.axvline(x=2.0, color='black', linestyle='-', linewidth=1)

# Get handles and labels
handles, labels = axes.get_legend_handles_labels()

# Remove duplicates
handle_dict = dict(zip(labels, handles))
axes.legend(handle_dict.values(), handle_dict.keys(), loc='upper left', fontsize=18, ncol=1)
# axes.legend()

plt.tight_layout()
plt.savefig('motivation_nv_pred.pdf')
plt.show()

# %%
mobnet_b = yolo[yolo['Category'] == 'B']
np.abs((mobnet_b['Observed_Power'] - mobnet_b['NV_Predicted'])/mobnet_b['Observed_Power']*100)
# Out:
# 3    193.811752
# dtype: float64
