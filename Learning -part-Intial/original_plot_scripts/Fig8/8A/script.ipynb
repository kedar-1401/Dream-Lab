# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
time = (11.3, 14.9, 12.8)
labels = ['RR*', '->MR', '->RM']
colors = ['#fadc6f','#a36268','#e36668']

df1 = pd.DataFrame({'Time': time}, index=labels)
print(df1)
# Out:
#       Time
# RR*   11.3
# ->MR  14.9
# ->RM  12.8

# %%
time = [11.3, 14.9, 12.8]
power = [6.9, 4.8, 7.2]

time2 = [13.2, 11.7, 12.9]
power2 = [6.1, 5.4, 7.2]

labels = ['RR*', '->MR', '->RM']
labels2 = ['MM*', '->MR', '->RM']
labels = ['RR*', '->MR', '->RM', 'MM*', '->MR', '->RM']

# %%
labels = ['RR*', '->MR']
data = {'a': (11.3, 13.2), 'b': (14.9, 11.7), 'c': (12.8, 12.9),}

colors = ['#fadc6f','#FA8079','#e36668']
x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(6, 4))

for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, edgecolor='darkgrey', color = colors[multiplier])
    # ax.bar_label(rects, padding=3)
    multiplier += 1

ax.set_ylabel('Time MAPE(%)', fontsize=14)
ax.set_xticks(x + width, labels)
# ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 16)



ax2 = ax.twinx()
ax2.plot(0, 6.9, color='#a09040', marker = '^', linestyle = 'none', markeredgecolor = 'darkgrey', markersize = 10)
ax2.plot(width, 4.8, color='#762e30', marker = '^', linestyle = 'none', markeredgecolor = 'darkgrey', markersize = 10)
ax2.plot(2*width, 7.2, color='#762e30', marker = '^', linestyle = 'none', markeredgecolor = 'darkgrey', markersize = 10)

ax2.plot(7*width - width/3, 6.1, color='#a09040', marker = '^', linestyle = 'none', markeredgecolor = 'darkgrey', markersize = 10)
ax2.plot(8*width - width/3, 5.4, color='#762e30', marker = '^', linestyle = 'none', markeredgecolor = 'darkgrey', markersize = 10)
ax2.plot(9*width - width/3, 7.2, color='#762e30', marker = '^', linestyle = 'none', markeredgecolor = 'darkgrey', markersize = 10)


ax2.tick_params(axis='y', labelsize=14)
ax2.set_ylim(0, 8)
ax2.set_ylabel('Power MAPE(%)', fontsize=14)

ax.yaxis.grid(which="minor", linestyle="--", linewidth=0.25, color="lightgrey")
ax.yaxis.grid(which="major", linestyle="-", linewidth=0.25, color="grey")
ax.set_axisbelow(True)

plt.show()

# %%
time = [11.3, 14.9, 12.8]
labels = ['RR*', '->MR', '->RM']
colors = ['#fadc6f','#a36268','#e36668']

# %%
labels = ['RR*', '->MR']
data = {'a': (11.3, 13.2), 'b': (14.9, 11.7), 'c': (12.8, 12.9),}

colors = ['#fadc6f','#FA8079','#e36668']
x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(6, 4))

for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, edgecolor='darkgrey', color = colors[multiplier])
    # ax.bar_label(rects, padding=3)
    multiplier += 1

ax.set_ylabel('Time MAPE(%)', fontsize=14)
ax.set_xticks(x + width, labels)
# ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 16)



ax2 = ax.twinx()
ax2.plot(0, 6.9, color='#a09040', marker = '^', linestyle = 'none', markeredgecolor = 'darkgrey', markersize = 10)
ax2.plot(width, 4.8, color='#762e30', marker = '^', linestyle = 'none', markeredgecolor = 'darkgrey', markersize = 10)
ax2.plot(2*width, 7.2, color='#762e30', marker = '^', linestyle = 'none', markeredgecolor = 'darkgrey', markersize = 10)

ax2.plot(7*width - width/3, 6.1, color='#a09040', marker = '^', linestyle = 'none', markeredgecolor = 'darkgrey', markersize = 10)
ax2.plot(8*width - width/3, 5.4, color='#762e30', marker = '^', linestyle = 'none', markeredgecolor = 'darkgrey', markersize = 10)
ax2.plot(9*width - width/3, 7.2, color='#762e30', marker = '^', linestyle = 'none', markeredgecolor = 'darkgrey', markersize = 10)


ax2.tick_params(axis='y', labelsize=14)
ax2.set_ylim(0, 8)
ax2.set_ylabel('Power MAPE(%)', fontsize=14)

ax.yaxis.grid(which="minor", linestyle="--", linewidth=0.25, color="lightgrey")
ax.yaxis.grid(which="major", linestyle="-", linewidth=0.25, color="grey")
ax.set_axisbelow(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ['RR*', '->MR']
data = {'a': (11.3, 13.2), 'b': (14.9, 11.7), 'c': (12.8, 12.9)}

colors = ['#fadc6f', '#FA8079', '#e36668']
x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(4, 4))
bars=[]
for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, edgecolor='darkgrey', color=colors[multiplier])
    #bars.append(rects[0])
    multiplier += 1

ax.set_ylabel('Time MAPE(%)', fontsize=14)

# Setting custom x-ticks and labels
custom_xticks = [0, 0.15, 0.3, 1, 1.15, 1.3]  # Custom positions for x-ticks
custom_labels = ['RR*', '->MR', '->RM', 'MM*', '->MR', '->RM']
ax.set_xticks(custom_xticks)
ax.set_xticklabels(custom_labels, rotation=45, fontsize=16)
ax.set_yticks([0, 4, 8, 12, 16])
ax.set_ylim(0, 16)

ax2 = ax.twinx()
ax2.plot(0, 6.9, color='#a09040', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(width, 4.8, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(2 * width, 7.2, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)

ax2.plot(7 * width - width / 3, 6.1, color='#a09040', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(8 * width - width / 3, 5.4, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(9 * width - width / 3, 7.2, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)

ax2.tick_params(axis='y', labelsize=14)
ax2.set_yticks([0, 2, 4, 6, 8])
ax2.set_ylim(0, 8)
ax2.set_ylabel('Power MAPE(%)', fontsize=14)

ax.yaxis.grid(which="minor", linestyle="--", linewidth=0.25, color="lightgrey")
ax.yaxis.grid(which="major", linestyle="-", linewidth=0.25, color="grey")
ax.set_axisbelow(True)



plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

labels = ['RR*', '->MR']
data = {'a': (11.3, 13.2), 'b': (14.9, 11.7), 'c': (12.8, 12.9)}

colors = ['#fadc6f', '#FA8079', '#e36668']
x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(6, 4))
bars=[]
for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, edgecolor='darkgrey', color=colors[multiplier])
    bars.append(rects[0])
    multiplier += 1

ax.set_ylabel('Time MAPE(%)', fontsize=14)

# Setting custom x-ticks and labels
custom_xticks = [0, 0.15, 0.3, 1, 1.15, 1.3]  # Custom positions for x-ticks
custom_labels = ['RR*', '->MR', '->RM', 'MM*', '->MR', '->RM']
ax.set_xticks(custom_xticks)
ax.set_xticklabels(custom_labels, rotation=45, fontsize=12)
ax.set_yticks([0, 4, 8, 12, 16])
ax.set_ylim(0, 16)

ax2 = ax.twinx()
ax2.plot(0, 6.9, color='#a09040', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(width, 4.8, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(2 * width, 7.2, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)

ax2.plot(7 * width - width / 3, 6.1, color='#a09040', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(8 * width - width / 3, 5.4, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(9 * width - width / 3, 7.2, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)

ax2.tick_params(axis='y', labelsize=14)
ax2.set_yticks([0, 2, 4, 6, 8])
ax2.set_ylim(0, 8)
ax2.set_ylabel('Power MAPE(%)', fontsize=14)

ax.yaxis.grid(which="minor", linestyle="--", linewidth=0.25, color="lightgrey")
ax.yaxis.grid(which="major", linestyle="-", linewidth=0.25, color="grey")
ax.set_axisbelow(True)

# Create custom legend
legend_elements = [
    Patch(facecolor='#fadc6f', edgecolor='black', label='NN Ref Time'),
    Patch(facecolor='#FA8079', edgecolor='black', label='PT Time'),
    Patch(facecolor='#e36668', edgecolor='black', label='PT Time'),
    Line2D([0], [0], marker='^', color='w', markerfacecolor='#a09040', markersize=10, label='NN Ref Power'),
    Line2D([0], [0], marker='^', color='w', markerfacecolor='#762e30', markersize=10, label='PT Power')
]

# Add the legend to the plot
ax.legend(handles=legend_elements, loc='lower right', fontsize=10)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

labels = ['RR*', '->MR']
data = {'a': (11.3, 13.2), 'b': (14.9, 11.7), 'c': (12.8, 12.9)}

colors = ['#fadc6f', '#FA8079', '#e36668']
x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(6, 4))
bars=[]
for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, edgecolor='darkgrey', color=colors[multiplier])
    bars.append(rects[0])
    multiplier += 1

ax.set_ylabel('Time MAPE(%)', fontsize=14)

# Setting custom x-ticks and labels
custom_xticks = [0, 0.15, 0.3, 1, 1.15, 1.3]  # Custom positions for x-ticks
custom_labels = ['RR*', '->MR', '->RM', 'MM*', '->MR', '->RM']
ax.set_xticks(custom_xticks)
ax.set_xticklabels(custom_labels, rotation=45, fontsize=12)
ax.set_yticks([0, 4, 8, 12, 16])
ax.set_ylim(0, 16)

ax2 = ax.twinx()
ax2.plot(0, 6.9, color='#a09040', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(width, 4.8, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(2 * width, 7.2, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)

ax2.plot(7 * width - width / 3, 6.1, color='#a09040', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(8 * width - width / 3, 5.4, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(9 * width - width / 3, 7.2, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)

ax2.tick_params(axis='y', labelsize=14)
ax2.set_yticks([0, 2, 4, 6, 8])
ax2.set_ylim(0, 8)
ax2.set_ylabel('Power MAPE(%)', fontsize=14)

ax.yaxis.grid(which="minor", linestyle="--", linewidth=0.25, color="lightgrey")
ax.yaxis.grid(which="major", linestyle="-", linewidth=0.25, color="grey")
ax.set_axisbelow(True)

# Create custom legend
legend_elements = [
    Patch(facecolor='#fadc6f', edgecolor='black', label='NN Ref Time'),
    Patch(facecolor='#FA8079', edgecolor='black', label='PT Time'), 
    Patch(facecolor='#e36668', edgecolor='black', label='PT Time'), # Added missing Patch
    Line2D([0], [0], marker='^', color='w', markerfacecolor='#a09040', markersize=10, label='NN Ref Power'),
    Line2D([0], [0], marker='^', color='w', markerfacecolor='#762e30', markersize=10, label='PT Power')
]

# Add the legend to the plot
ax.legend(handles=legend_elements, loc='lower right', fontsize=10)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

labels = ['RR*', '->MR']
data = {'a': (11.3, 13.2), 'b': (14.9, 11.7), 'c': (12.8, 12.9)}

colors = ['#fadc6f', '#FA8079', '#e36668']
x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(6, 4))
bars=[]
for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, edgecolor='darkgrey', color=colors[multiplier])
    bars.append(rects[0])
    multiplier += 1

ax.set_ylabel('Time MAPE(%)', fontsize=14)

# Setting custom x-ticks and labels
custom_xticks = [0, 0.15, 0.3, 1, 1.15, 1.3]  # Custom positions for x-ticks
custom_labels = ['RR*', '->MR', '->RM', 'MM*', '->MR', '->RM']
ax.set_xticks(custom_xticks)
ax.set_xticklabels(custom_labels, rotation=45, fontsize=12)
ax.set_yticks([0, 4, 8, 12, 16])
ax.set_ylim(0, 16)

ax2 = ax.twinx()
ax2.plot(0, 6.9, color='#a09040', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(width, 4.8, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(2 * width, 7.2, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)

ax2.plot(7 * width - width / 3, 6.1, color='#a09040', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(8 * width - width / 3, 5.4, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(9 * width - width / 3, 7.2, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)

ax2.tick_params(axis='y', labelsize=14)
ax2.set_yticks([0, 2, 4, 6, 8])
ax2.set_ylim(0, 8)
ax2.set_ylabel('Power MAPE(%)', fontsize=14)

ax.yaxis.grid(which="minor", linestyle="--", linewidth=0.25, color="lightgrey")
ax.yaxis.grid(which="major", linestyle="-", linewidth=0.25, color="grey")
ax.set_axisbelow(True)

# Create custom legend
legend_elements = [
    Patch(facecolor='#fadc6f', edgecolor='black', label='NN Ref Time'),
    Patch(facecolor='#FA8079', edgecolor='black', label='PT Time'), 
    Patch(facecolor='#e36668', edgecolor='black', label='PT Time'), # Added missing Patch
    Line2D([0], [0], marker='^', color='w', markerfacecolor='#a09040', markersize=10, label='NN Ref Power'),
    Line2D([0], [0], marker='^', color='w', markerfacecolor='#762e30', markersize=10, label='PT Power')
]

# Add the legend to the plot
ax.legend(handles=[legend_elements[1],legend_elements[2]], labels=['','PT Time'], loc='lower right', fontsize=10, labelspacing=0.2, columnspacing=0, handletextpad=0.1, fancybox=True, ncol = 2)
# ax2.legend(handles=[legend_elements[0], legend_elements[3], legend_elements[4]], labels=['NN Ref Time','NN Ref Power','PT Power'], loc='lower right', fontsize=10)

plt.show()

# %%
#ax.legend(handles=legend_elements, loc='lower right', fontsize=10)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

labels = ['RR*', '->MR']
data = {'a': (11.3, 13.2), 'b': (14.9, 11.7), 'c': (12.8, 12.9)}

colors = ['#fadc6f', '#FA8079', '#e36668']
x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(6, 4))
bars=[]
for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, edgecolor='darkgrey', color=colors[multiplier])
    bars.append(rects[0])
    multiplier += 1

ax.set_ylabel('Time MAPE(%)', fontsize=14)

# Setting custom x-ticks and labels
custom_xticks = [0, 0.15, 0.3, 1, 1.15, 1.3]  # Custom positions for x-ticks
custom_labels = ['RR*', '->MR', '->RM', 'MM*', '->MR', '->RM']
ax.set_xticks(custom_xticks)
ax.set_xticklabels(custom_labels, rotation=45, fontsize=12)
ax.set_yticks([0, 4, 8, 12, 16])
ax.set_ylim(0, 16)

ax2 = ax.twinx()
ax2.plot(0, 6.9, color='#a09040', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(width, 4.8, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(2 * width, 7.2, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)

ax2.plot(7 * width - width / 3, 6.1, color='#a09040', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(8 * width - width / 3, 5.4, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(9 * width - width / 3, 7.2, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)

ax2.tick_params(axis='y', labelsize=14)
ax2.set_yticks([0, 2, 4, 6, 8])
ax2.set_ylim(0, 8)
ax2.set_ylabel('Power MAPE(%)', fontsize=14)

ax.yaxis.grid(which="minor", linestyle="--", linewidth=0.25, color="lightgrey")
ax.yaxis.grid(which="major", linestyle="-", linewidth=0.25, color="grey")
ax.set_axisbelow(True)

# Create custom legend
legend_elements = [
    Patch(facecolor='#fadc6f', edgecolor='darkgrey', label='NN Ref Time'),
    Patch(facecolor='#FA8079', edgecolor='darkgrey', label='PT Time'), 
    Patch(facecolor='#e36668', edgecolor='darkgrey', label='PT Time'), # Added missing Patch'
    # Patch(facecolor='white', label='PT Time'), # Added missing Patch
    Line2D([0], [0], marker='^', color='w', markerfacecolor='#a09040', markersize=10, label='NN Ref Power'),
    Line2D([0], [0], marker='^', color='w', markerfacecolor='#762e30', markersize=10, label='PT Power')
]

# Merge legends
merged_legend_elements = [
    legend_elements[3], legend_elements[4], legend_elements[0], legend_elements[1], legend_elements[2]
]

# Add the legend to the plot
ax.legend(handles=merged_legend_elements, labels=['NN Ref Power ','PT Power ', 'NN Ref Time', 'PT Time', 'PT Time'], loc='lower right', fontsize=10, labelspacing=0.2, columnspacing=0, handletextpad=0.1, fancybox=True, ncol = 2)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.legend_handler import HandlerPatch
from matplotlib.collections import PatchCollection
import numpy as np

# Define an object that will be used by the legend
class MulticolorPatch(object):
    def __init__(self, colors):
        self.colors = colors

# Define a handler for the MulticolorPatch object
class MulticolorPatchHandler(HandlerPatch):
    def create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans):
        patches = []
        for i, c in enumerate(orig_handle.colors):
            patches.append(plt.Rectangle([xdescent + i * width / len(orig_handle.colors),
                                          ydescent], 
                                          width / len(orig_handle.colors), 
                                          height, 
                                          facecolor=c, 
                                          edgecolor='none', 
                                          transform=trans))
            
        patch = PatchCollection(patches,match_original=True)
        handlebox.add_artist(patch)
        return patches

# Define your data
labels = ['RR*', '->MR']
data = {'a': (11.3, 13.2), 'b': (14.9, 11.7), 'c': (12.8, 12.9)}

colors = ['#fadc6f', '#FA8079', '#e36668']
x = np.arange(len(labels))  # Ensure x is an array
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(6, 4))
bars = []
for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, edgecolor='darkgrey', color=colors[multiplier])
    bars.append(rects[0])
    multiplier += 1

ax.set_ylabel('Time MAPE(%)', fontsize=14)

# Setting custom x-ticks and labels
custom_xticks = [0, 0.15, 0.3, 1, 1.15, 1.3]  # Custom positions for x-ticks
custom_labels = ['RR*', '->MR', '->RM', 'MM*', '->MR', '->RM']
ax.set_xticks(custom_xticks)
ax.set_xticklabels(custom_labels, rotation=45, fontsize=12)
ax.set_yticks([0, 4, 8, 12, 16])
ax.set_ylim(0, 16)

ax2 = ax.twinx()
ax2.plot(0, 6.9, color='#a09040', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(width, 4.8, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(2 * width, 7.2, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)

ax2.plot(7 * width - width / 3, 6.1, color='#a09040', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(8 * width - width / 3, 5.4, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(9 * width - width / 3, 7.2, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)

ax2.tick_params(axis='y', labelsize=14)
ax2.set_yticks([0, 2, 4, 6, 8])
ax2.set_ylim(0, 8)
ax2.set_ylabel('Power MAPE(%)', fontsize=14)


# Create custom legend
legend_elements = [
    Patch(facecolor='#fadc6f', edgecolor='darkgrey', label='NN Ref Time'),
    Patch(facecolor='#FA8079', edgecolor='darkgrey', label='PT Time'),
    Patch(facecolor='#e36668', edgecolor='darkgrey', label='PT Time'),  # MulticolorPatch
    Line2D([0], [0], marker='^', color='w', markerfacecolor='#a09040', markersize=10, label='NN Ref Power'),
    Line2D([0], [0], marker='^', color='w', markerfacecolor='#762e30', markersize=10, label='PT Power')
]

# Merge legends
merged_legend_elements = [
    legend_elements[0], legend_elements[1], legend_elements[2], legend_elements[3], legend_elements[4]
]

# Add the legend to the plot
ax.legend(handles=merged_legend_elements, labels=['NN Ref Time', 'PT Time', 'PT Time', 'NN Ref Power', 'PT Power'], loc='lower right', fontsize=10, labelspacing=0.2, columnspacing=0, handletextpad=0.1, fancybox=True, ncol=2,
          handler_map={Patch: HandlerPatch(), MulticolorPatch: MulticolorPatchHandler()})

# plt.show()
plt.savefig('gen_new_DNN_bar.pdf', format='pdf',dpi=300)#, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.legend_handler import HandlerPatch
from matplotlib.collections import PatchCollection
from matplotlib.lines import Line2D
import numpy as np

# Define an object that will be used by the legend
class MulticolorPatch(object):
    def __init__(self, colors):
        self.colors = colors

# Define a handler for the MulticolorPatch object
class MulticolorPatchHandler(HandlerPatch):
    def create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans):
        patches = []
        for i, c in enumerate(orig_handle.colors):
            patches.append(plt.Rectangle([xdescent + i * width / len(orig_handle.colors),
                                          ydescent], 
                                          width / len(orig_handle.colors), 
                                          height, 
                                          facecolor=c, 
                                          edgecolor='none', 
                                          transform=trans))
            
        patch = PatchCollection(patches,match_original=True)
        handlebox.add_artist(patch)
        return patches

# Define your data
labels = ['RR*', '->MR']
data = {'a': (11.3, 13.2), 'b': (14.9, 11.7), 'c': (12.8, 12.9)}

colors = ['#fadc6f', '#FA8079', '#e36668']
x = np.arange(len(labels))  # Ensure x is an array
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(6, 4))
plt.minorticks_on()
ax.yaxis.grid(which="minor", linestyle="--", linewidth=0.25, color="lightgrey")
ax.yaxis.grid(which="major", linestyle="-", linewidth=0.25, color="grey")
# ax.xaxis.grid(which="major", linestyle="-", linewidth=0.25, color="grey")
# ax.xaxis.grid(which="minor", linestyle="--", linewidth=0.25, color="lightgrey")
ax.set_axisbelow(True)
bars = []
for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, edgecolor='darkgrey', color=colors[multiplier])
    bars.append(rects[0])
    multiplier += 1
# Add gridlines

ax.set_ylabel('Time MAPE(%)', fontsize=20)

# Setting custom x-ticks and labels
custom_xticks = [0, 0.15, 0.3, 1, 1.15, 1.3]  # Custom positions for x-ticks
custom_labels = ['RR*', '->MR', '->RM', 'MM*', '->MR', '->RM']
ax.set_xticks(custom_xticks)
ax.set_xticklabels(custom_labels, rotation=45, fontsize=20)
ax.tick_params(axis='y', labelsize=20)
ax.set_yticks([0, 4, 8, 12, 16])
ax.set_ylim(0, 16)

ax2 = ax.twinx()
ax2.plot(0, 6.9, color='#a09040', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(width, 4.8, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(2 * width, 7.2, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)

ax2.plot(7 * width - width / 3, 6.1, color='#a09040', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(8 * width - width / 3, 5.4, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)
ax2.plot(9 * width - width / 3, 7.2, color='#762e30', marker='^', linestyle='none', markeredgecolor='darkgrey', markersize=10)

ax2.tick_params(axis='y', labelsize=20)
ax2.set_yticks([0, 2, 4, 6, 8])
ax2.set_ylim(0, 8)
ax2.set_ylabel('Power MAPE(%)', fontsize=20)




# Create custom legend
legend_elements = [
    Patch(facecolor='#fadc6f', edgecolor='darkgrey', label='NN Ref Time'),
    Patch(facecolor='#FA8079', edgecolor='darkgrey', label='PT Time'),
    Patch(facecolor='#e36668', edgecolor='darkgrey', label='PT Time'),  # MulticolorPatch
    Line2D([0], [0], marker='^', color='w', markerfacecolor='#a09040', markersize=10, label='NN Ref Power'),
    Line2D([0], [0], marker='^', color='w', markerfacecolor='#762e30', markersize=10, label='PT Power')
]

# Merge legends
merged_legend_elements = [
    legend_elements[0], legend_elements[1], legend_elements[2], legend_elements[3], legend_elements[4]
]

# Add the legend to the plot
ax.legend(handles=merged_legend_elements, labels=['NN Ref Time', 'PT Time', 'PT Time', 'NN Ref Power', 'PT Power'], loc='lower right', fontsize=18, labelspacing=0.2, columnspacing=0, handletextpad=0.1, fancybox=True, ncol=2,
          handler_map={Patch: HandlerPatch(), MulticolorPatch: MulticolorPatchHandler()})

# plt.show()
plt.savefig('gen_new_DNN_bar.pdf', format='pdf',dpi=300, bbox_inches='tight')

plt.show()
