# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.patches as patches
# Sample data for the demonstration
data = {
    'gpu': [
        220, 318, 522, 726, 930, 1134, 1300,
    ],
    'observed_time': [
        75.800255, 39.082688, 18.313264, 13.825200,11.510480, 11.098352, 10.931968,
    ]
}


group = pd.DataFrame(data)

# Define the CPU frequency and colors
cpu_freq = 2201  # Example CPU frequency in MHz
colors = ['green']  # Example colors list
count = 0  # Starting index for colors

fig, ax = plt.subplots(figsize=(5, 5))

# Plotting the data
plt.plot(group['gpu'], group['observed_time'], marker='', label=f'{cpu_freq} MHz', linestyle='-', markersize=5, color=colors[count])
count += 1

# Add labels, title, and legend
plt.xlabel('GPU Frequency')
plt.ylabel('Minibatch Time (ms)')
# plt.title('GPU Frequency vs Minibatch Time (ms)')

ax.grid(which='major', linestyle='-', linewidth='0.5', color='darkgrey', alpha=1)
ax.grid(which='minor', linestyle='-', linewidth='0.25', color='lightgray')
ax.set_axisbelow(True)

plt.xlim(0, 1500)  # Adjust the limits as per your data range
plt.ylim(0, 81) 
# Show the plot

plt.plot([220, 726], [75.800255, 13.825200], color='skyblue', linewidth=1, linestyle='-')
plt.plot([318, 726], [39.082680,13.825200], color='skyblue', linewidth=1, linestyle='-')

# Adding text labels
plt.text((220 + 726) / 2+40, (75.800255 + 13.825200) / 2, 'm1', color='skyblue', fontsize=12, ha='center')
plt.text((318 + 726) / 2+40, (39.082688 + 13.825200) / 2, 'm2', color='skyblue', fontsize=12, ha='center')


plt.text((150), (73.800255) , 'low', color='black', fontsize=12, ha='center')
plt.text((220), (38.082688), 'mid2', color='black', fontsize=12, ha='center')
plt.text((726), (8.825200), 'mid1', color='black', fontsize=12, ha='center')

plt.text((220), (73.800255) , 'X', color='black', fontsize=12, ha='center')
plt.text((318), (38.082688), 'X', color='black', fontsize=12, ha='center')
plt.text((726), (11.825200), 'X', color='black', fontsize=12, ha='center')
# brace = patches.FancyBboxPatch(
#     (200, 50),  # (x, y) position
#     50, 25,    # width, height
#     boxstyle="round,pad=0.3,rounding_size=0.15",
#     ec="red",
#     fc="none",
#     mutation_aspect=1.5
# )
# plt.gca().add_patch(brace)

plt.text(200, 60, 'Pruned by GMD', fontsize=10, color='red', ha='center', va='center' ,rotation=-80)
# plt.savefig('Binary_Search_Curve.pdf', format='pdf',dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample data for the demonstration
data = {
    'gpu': [220, 318, 522, 726, 930, 1134, 1300],
    'observed_time': [75.800255, 39.082688, 18.313264, 13.825200, 11.510480, 11.098352, 10.931968]
}

group = pd.DataFrame(data)

# Define the CPU frequency and colors
cpu_freq = 2201  # Example CPU frequency in MHz
colors = ['green']  # Example colors list
count = 0  # Starting index for colors

fig, ax = plt.subplots(figsize=(10, 7))  # Slightly larger figure for better visibility

# Plotting the data
plt.plot(group['gpu'], group['observed_time'], marker='', label=f'{cpu_freq} MHz', linestyle='-', markersize=5, color=colors[count])
count += 1

# Add labels, title, and legend
plt.xlabel('GPU Frequency (MHz)', fontsize=22)
plt.ylabel('Minibatch Time (ms)', fontsize=22)
# plt.title('GPU Frequency vs Minibatch Time (ms)', fontsize=22)

# Enable major and minor grids
ax.grid(which='major', linestyle='-', linewidth='0.5', color='darkgrey', alpha=1)
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray', alpha=1)

# Enable minor ticks
ax.minorticks_on()
ax.set_axisbelow(True)  

plt.xlim(0, 1500)  # Adjust the limits as per your data range
plt.ylim(0, 81)

# Show the plot
plt.plot([220, 726], [75.800255, 13.825200], color='skyblue', linewidth=1, linestyle='-')
plt.plot([318, 726], [39.082688, 13.825200], color='skyblue', linewidth=1, linestyle='-')

# Adding text labels
plt.text((220 + 726) / 2 + 40, (75.800255 + 13.825200) / 2, 'm1', color='skyblue', fontsize=22, ha='center')
plt.text((318 + 726) / 2 + 40, (39.082688 + 13.825200) / 2, 'm2', color='skyblue', fontsize=22, ha='center')

plt.text(130, 73.800255, 'low', color='black', fontsize=22, ha='center')
plt.text(190, 38.082688, 'mid2', color='black', fontsize=22, ha='center')
plt.text(726, 8.825200, 'mid1', color='black', fontsize=22, ha='center')

plt.text(220, 73.800255, 'X', color='black', fontsize=18, ha='center')
plt.text(318, 38.082688, 'X', color='black', fontsize=18, ha='center')
plt.text(726, 11.825200, 'X', color='black', fontsize=18, ha='center')

plt.text(200, 58, 'Pruned by GMD', fontsize=18, color='red', ha='center', va='center', rotation=-80)

# Set the tick parameters
ax.tick_params(axis='both', which='major', labelsize=22)
ax.tick_params(axis='both', which='minor', labelsize=16)

# plt.savefig('Binary_Search_Curve.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample data for the demonstration
data = {
    'gpu': [220, 318, 522, 726, 930, 1134, 1300],
    'observed_time': [75.800255, 39.082688, 18.313264, 13.825200, 11.510480, 11.098352, 10.931968]
}

group = pd.DataFrame(data)

# Define the CPU frequency and colors
cpu_freq = 2201  # Example CPU frequency in MHz
colors = ['green']  # Example colors list
count = 0  # Starting index for colors

fig, ax = plt.subplots(figsize=(7, 7))  # Slightly larger figure for better visibility

# Plotting the data
plt.plot(group['gpu'], group['observed_time'], marker='', label=f'{cpu_freq} MHz', linestyle='-', markersize=5, color=colors[count])
count += 1

# Add labels, title, and legend
plt.xlabel('GPU Freq. (MHz)', fontsize=22)
plt.ylabel('Minibatch Time (ms)', fontsize=22)
# plt.title('GPU Frequency vs Minibatch Time (ms)', fontsize=22)

# Enable major and minor grids
ax.grid(which='major', linestyle='-', linewidth='0.5', color='darkgrey', alpha=1)
ax.grid(which='minor', linestyle='-', linewidth='0.25', color='lightgray')

# Enable minor ticks
ax.minorticks_on()
ax.set_axisbelow(True)  

plt.xlim(0, 1500)  # Adjust the limits as per your data range
plt.ylim(0, 81)

# Show the plot
plt.plot([220, 726], [75.800255, 13.825200], color='skyblue', linewidth=1, linestyle='-')
plt.plot([318, 726], [39.082688, 13.825200], color='skyblue', linewidth=1, linestyle='-')

# Adding text labels
plt.text((220 + 726) / 2 + 40, (80.800255 + 13.825200) / 2, 'm1', color='skyblue', fontsize=22, ha='center')
plt.text((318 + 726) / 2 + 40, (39.082688 + 13.825200) / 2, 'm2', color='skyblue', fontsize=22, ha='center')

plt.text(130, 73.800255, 'low', color='black', fontsize=22, ha='center')
plt.text(190, 38.082688, 'mid2', color='black', fontsize=22, ha='center')
plt.text(726, 8.825200, 'mid1', color='black', fontsize=22, ha='center')

plt.text(220, 73.800255, 'X', color='black', fontsize=18, ha='center')
plt.text(318, 38.082688, 'X', color='black', fontsize=18, ha='center')
plt.text(726, 11.825200, 'X', color='black', fontsize=18, ha='center')

plt.text(200, 58, 'Pruned by GMD', fontsize=18, color='red', ha='center', va='center', rotation=-80)

# Set the tick parameters
ax.tick_params(axis='both', which='major', labelsize=22)
ax.tick_params(axis='both', which='minor', labelsize=16)

plt.savefig('Binary_Search_Curve.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.show()
